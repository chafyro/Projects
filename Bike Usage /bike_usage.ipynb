# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bike_data = pd.read_csv('train.csv')

# %%
pd.to_datetime('230719-00:10:00')
# Out:
# Timestamp('2019-07-23 00:10:00')

# %%
bike_data
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
bike_data['datetime'] = pd.to_datetime(bike_data['datetime'])

bike_data['year'] = bike_data['datetime'].dt.year
bike_data['month'] = bike_data['datetime'].dt.month
bike_data['day'] = bike_data['datetime'].dt.day
bike_data['day_of_week'] = bike_data['datetime'].dt.dayofweek
bike_data['hour'] = bike_data['datetime'].dt.hour
bike_data['Temperature '] = bike_data['temp']

bike_data.drop('temp', axis=1, inplace=True)
bike_data.drop('atemp', axis=1, inplace=True)
bike_data.drop('workingday', axis=1, inplace=True)

# %%
bike_data.index.inferred_type
# Out:
# 'integer'

# %%
bike_data
# Out:
#                  datetime  season  holiday  weather  humidity  windspeed  \
# 0     2011-01-01 00:00:00       1        0        1        81     0.0000
# 1     2011-01-01 01:00:00       1        0        1        80     0.0000
# 2     2011-01-01 02:00:00       1        0        1        80     0.0000
# 3     2011-01-01 03:00:00       1        0        1        75     0.0000
# 4     2011-01-01 04:00:00       1        0        1        75     0.0000
# ...                   ...     ...      ...      ...       ...        ...
# 10881 2012-12-19 19:00:00       4        0        1        50    26.0027
# 10882 2012-12-19 20:00:00       4        0        1        57    15.0013
# 10883 2012-12-19 21:00:00       4        0        1        61    15.0013
# 10884 2012-12-19 22:00:00       4        0        1        61     6.0032
# 10885 2012-12-19 23:00:00       4        0        1        66     8.9981
#
#        casual  registered  count  year  month  day  day_of_week  hour  \
# ...

# %%
date_range = pd.date_range('jan 1 2011', '31 jan 2011', freq = '12h')

# %%
date_range
# Out:
# DatetimeIndex(['2011-01-01 00:00:00', '2011-01-01 12:00:00',
#                '2011-01-02 00:00:00', '2011-01-02 12:00:00',
#                '2011-01-03 00:00:00', '2011-01-03 12:00:00',
#                '2011-01-04 00:00:00', '2011-01-04 12:00:00',
#                '2011-01-05 00:00:00', '2011-01-05 12:00:00',
#                '2011-01-06 00:00:00', '2011-01-06 12:00:00',
#                '2011-01-07 00:00:00', '2011-01-07 12:00:00',
#                '2011-01-08 00:00:00', '2011-01-08 12:00:00',
#                '2011-01-09 00:00:00', '2011-01-09 12:00:00',
#                '2011-01-10 00:00:00', '2011-01-10 12:00:00',
#                '2011-01-11 00:00:00', '2011-01-11 12:00:00',
#                '2011-01-12 00:00:00', '2011-01-12 12:00:00',
#                '2011-01-13 00:00:00', '2011-01-13 12:00:00',
#                '2011-01-14 00:00:00', '2011-01-14 12:00:00',
#                '2011-01-15 00:00:00', '2011-01-15 12:00:00',
# ...

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
print(df['datetime'].dtype)
# Out:
# object

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
print(df['datetime'].dtype)
# Out:
# datetime64[ns]

# %%
df['month'] = df['datetime'].dt.month
df['day'] = df['datetime'].dt.day
df['year'] = df['datetime'].dt.year
df['hour'] = df['datetime'].dt.dayofweek

# %%
df
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count  month  day  \
# ...

# %%
df['timestamp'] = pd.to_datetime(df['datetime'])

df.set_index('timestamp', inplace=True)

# %%
grouped_data = df.resample('M').mean()
# Out:
# /var/folders/43/x27mnfmj389_d9977vqn02tc0000gn/T/ipykernel_7510/3092112332.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_data = df.resample('M').mean()

# %%
grouped_data = grouped_data[['weather', 'temp', 'holiday', 'windspeed', 'count', 'season', 'count']]
grouped_data
# Out:
#              weather       temp   holiday  windspeed       count  season  \
# timestamp
# 2011-01-31  1.440835   8.633782  0.055684  13.749830   54.645012     1.0
# 2011-02-28  1.378924  11.331076  0.000000  15.509298   73.641256     1.0
# 2011-03-31  1.466368  14.063184  0.000000  16.033866   86.849776     1.0
# 2011-04-30  1.619780  17.776879  0.052747  15.844234  111.026374     2.0
# 2011-05-31  1.528509  21.528596  0.000000  12.355358  174.809211     2.0
# 2011-06-30  1.278509  28.191096  0.000000  11.930099  196.877193     2.0
# 2011-07-31  1.184211  29.967763  0.052632  11.960793  203.614035     3.0
# 2011-08-31  1.344298  29.667456  0.000000  12.480543  182.666667     3.0
# 2011-09-30  1.618102  25.141236  0.052980  11.501445  174.622517     3.0
# 2011-10-31  1.534066  20.903692  0.052747  10.971832  174.773626     4.0
# 2011-11-30  1.333333  16.036754  0.052632  12.112219  155.458333     4.0
# 2011-12-31  1.392544  12.897018  0.000000  10.803133  134.173246     4.0
# ...

# %%
sns.lineplot(data=df, x='datetime', y='count')
plt.xlabel('Date')
plt.ylabel('Count')
plt.title('Bike Counts over Time')
plt.xticks(rotation=45)
plt.show()

# %%
def bike_usage_by_season(df):
    
    season_counts = df.groupby('season')['count'].sum()
    
    season_labels = ['Spring', 'Summer', 'Fall', 'Winter']

    plt.bar(season_labels, season_counts)
    plt.xlabel('Season')
    plt.ylabel('Bike Usage')
    plt.title('Bike Usage by Season')

# %%
bike_usage_by_season(df)
